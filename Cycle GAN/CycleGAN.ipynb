# %% [markdown]
# ## **Homework 2** Problem 3
#
# In this assignment, you will try to implement CycleGAN to do style transform.

# %% [markdown]
# ### (a) Installation
#
# Install the CycleGAN package from the official GitHub repository.

# %%
# !git clone https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix
# Out:
# Cloning into 'pytorch-CycleGAN-and-pix2pix'...
# remote: Enumerating objects: 2428, done.
# remote: Total 2428 (delta 0), reused 0 (delta 0), pack-reused 2428
# Receiving objects: 100% (2428/2428), 8.13 MiB | 25.00 MiB/s, done.
# Resolving deltas: 100% (1561/1561), done.

# %%
import os
os.chdir('pytorch-CycleGAN-and-pix2pix/')

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 676 kB 8.9 MB/s
# ...
#      |████████████████████████████████| 1.7 MB 40.6 MB/s
# ...
#      |████████████████████████████████| 52 kB 1.4 MB/s
# ...
#      |████████████████████████████████| 97 kB 6.4 MB/s
# ...
#      |████████████████████████████████| 139 kB 49.2 MB/s
# ...
#      |████████████████████████████████| 180 kB 50.6 MB/s
# ...
#      |████████████████████████████████| 63 kB 1.6 MB/s
# ...
#   Created wheel for visdom: filename=visdom-0.1.8.9-py3-none-any.whl size=655250 sha256=a664186113994bdb1200a58f6dfe49e7a5d6cf34165e6402d8ae1885508593dd
#   Stored in directory: /root/.cache/pip/wheels/2d/d1/9b/cde923274eac9cbb6ff0d8c7c72fe30a3da9095a38fd50bbf1
# ...
#   Created wheel for subprocess32: filename=subprocess32-3.5.4-py3-none-any.whl size=6502 sha256=c3691073d57b3d2dc68f5769be7d9b04cc53a091b15c273565e5a2bd6dcb09ec
#   Stored in directory: /root/.cache/pip/wheels/50/ca/fa/8fca8d246e64f19488d07567547ddec8eb084e8c0d7a59226a
# ...

# %% [markdown]
# Download the official zebra2horse dataset.

# %%
# !bash /content/pytorch-CycleGAN-and-pix2pix/datasets/download_cyclegan_dataset.sh horse2zebra
# Out:
# Specified [horse2zebra]
# WARNING: timestamping does nothing in combination with -O. See the manual
# for details.
#
# --2021-10-28 21:17:18--  http://efrosgans.eecs.berkeley.edu/cyclegan/datasets/horse2zebra.zip
# Resolving efrosgans.eecs.berkeley.edu (efrosgans.eecs.berkeley.edu)... 128.32.244.190
# Connecting to efrosgans.eecs.berkeley.edu (efrosgans.eecs.berkeley.edu)|128.32.244.190|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 116867962 (111M) [application/zip]
# Saving to: ‘./datasets/horse2zebra.zip’
#
# ./datasets/horse2ze 100%[===================>] 111.45M  4.27MB/s    in 30s
#
# 2021-10-28 21:17:48 (3.72 MB/s) - ‘./datasets/horse2zebra.zip’ saved [116867962/116867962]
#
# Archive:  ./datasets/horse2zebra.zip
#    creating: ./datasets/horse2zebra/trainA/
#   inflating: ./datasets/horse2zebra/trainA/n02381460_6223.jpg
#   inflating: ./datasets/horse2zebra/trainA/n02381460_1567.jpg
#   inflating: ./datasets/horse2zebra/trainA/n02381460_3354.jpg
# ...

# %% [markdown]
# ### (b) Train CycleGAN
#
# Train CycleGAN for about 5 epochs. Not necessary to finish training since it may cost a long time. Test your trained model and visualize some results.
#
# Note: Use `latest_net_G_A.pth` if you want to transform images from class A to class B and `latest_net_G_B.pth` if you want to transform images from class B to class A.

# %%
# !python train.py --dataroot /content/pytorch-CycleGAN-and-pix2pix/datasets/horse2zebra --name horse2zebra --model cycle_gan
# Out:
# ----------------- Options ---------------
#                batch_size: 1
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#                 crop_size: 256
#                  dataroot: /content/pytorch-CycleGAN-and-pix2pix/datasets/horse2zebra	[default: None]
#              dataset_mode: unaligned
#                 direction: AtoB
#               display_env: main
#              display_freq: 400
#                display_id: 1
#             display_ncols: 4
#              display_port: 8097
#            display_server: http://localhost
#           display_winsize: 256
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: True                          	[default: None]
#                  lambda_A: 10.0
# ...

# %% [markdown]
# ### (c) Infer from Pre-trained Model
#
# Download one of the official pretrained models.

# %%
# !bash ./scripts/download_cyclegan_model.sh horse2zebra  # or zebra2horse
# Out:
# Note: available models are apple2orange, orange2apple, summer2winter_yosemite, winter2summer_yosemite, horse2zebra, zebra2horse, monet2photo, style_monet, style_cezanne, style_ukiyoe, style_vangogh, sat2map, map2sat, cityscapes_photo2label, cityscapes_label2photo, facades_photo2label, facades_label2photo, iphone2dslr_flower
# Specified [horse2zebra]
# WARNING: timestamping does nothing in combination with -O. See the manual
# for details.
#
# --2021-10-28 21:52:12--  http://efrosgans.eecs.berkeley.edu/cyclegan/pretrained_models/horse2zebra.pth
# Resolving efrosgans.eecs.berkeley.edu (efrosgans.eecs.berkeley.edu)... 128.32.244.190
# Connecting to efrosgans.eecs.berkeley.edu (efrosgans.eecs.berkeley.edu)|128.32.244.190|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 45575747 (43M)
# Saving to: ‘./checkpoints/horse2zebra_pretrained/latest_net_G.pth’
#
# ./checkpoints/horse 100%[===================>]  43.46M  1.62MB/s    in 27s
#
# ...

# %%
# !bash ./scripts/download_cyclegan_model.sh zebra2horse
# Out:
# Note: available models are apple2orange, orange2apple, summer2winter_yosemite, winter2summer_yosemite, horse2zebra, zebra2horse, monet2photo, style_monet, style_cezanne, style_ukiyoe, style_vangogh, sat2map, map2sat, cityscapes_photo2label, cityscapes_label2photo, facades_photo2label, facades_label2photo, iphone2dslr_flower
# Specified [zebra2horse]
# WARNING: timestamping does nothing in combination with -O. See the manual
# for details.
#
# --2021-10-28 21:52:39--  http://efrosgans.eecs.berkeley.edu/cyclegan/pretrained_models/zebra2horse.pth
# Resolving efrosgans.eecs.berkeley.edu (efrosgans.eecs.berkeley.edu)... 128.32.244.190
# Connecting to efrosgans.eecs.berkeley.edu (efrosgans.eecs.berkeley.edu)|128.32.244.190|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 45575747 (43M)
# Saving to: ‘./checkpoints/zebra2horse_pretrained/latest_net_G.pth’
#
# ./checkpoints/zebra 100%[===================>]  43.46M  4.42MB/s    in 10s
#
# ...

# %% [markdown]
# Or copy your own pretrained model to `./checkpoints/{NAME}_pretrained/latest_net_G.pt`

# %%
cp ./checkpoints/horse2zebra/latest_net_G_A.pth ./checkpoints/horse2zebra/latest_net_G.pth

# %%
# !python test.py --dataroot datasets/horse2zebra/testA --name horse2zebra --model test --no_dropout
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#                 crop_size: 256
#                  dataroot: datasets/horse2zebra/testA    	[default: None]
#              dataset_mode: single
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
#                     model: test
#              model_suffix:
#                n_layers_D: 3
#                      name: horse2zebra                   	[default: experiment_name]
#                       ndf: 64
# ...

# %% [markdown]
# Test the style transform.
#
# Note: Change the `--dataroot` and `--name` to be consistent with your trained model's configuration.

# %%
# !python test.py --dataroot datasets/horse2zebra/testA --name horse2zebra_pretrained --model test --no_dropout
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#                 crop_size: 256
#                  dataroot: datasets/horse2zebra/testA    	[default: None]
#              dataset_mode: single
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
#                     model: test
#              model_suffix:
#                n_layers_D: 3
#                      name: horse2zebra_pretrained        	[default: experiment_name]
#                       ndf: 64
# ...

# %% [markdown]
# Visualize your results.

# %%
import matplotlib.pyplot as plt

img = plt.imread('./results/horse2zebra_pretrained/test_latest/images/n02381460_1010_real.png') #orginal image
plt.imshow(img)

# %%
import matplotlib.pyplot as plt

img = plt.imread('./results/horse2zebra_pretrained/test_latest/images/n02381460_1010_fake.png')
plt.imshow(img)

# %% [markdown]
# ### Try your customized images.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
img = plt.imread('/content/gdrive/MyDrive/UW Assignments/EE P 596 B Au 21/HW2/Somnath HW P3 images/Images/Many Horse Image.jpg')
plt.imshow(img)

# %%
# !python test.py --dataroot '/content/gdrive/MyDrive/UW Assignments/EE P 596 B Au 21/HW2/Somnath HW P3 images/Images/'  --name horse2zebra_pretrained --model test --no_dropout
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#                 crop_size: 256
#                  dataroot: /content/gdrive/MyDrive/UW Assignments/EE P 596 B Au 21/HW2/Somnath HW P3 images/Images/	[default: None]
#              dataset_mode: single
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
#                     model: test
#              model_suffix:
#                n_layers_D: 3
# ...

# %%
img = plt.imread('/content/pytorch-CycleGAN-and-pix2pix/results/horse2zebra_pretrained/test_latest/images/Many Horse Image-2_fake.png')
plt.imshow(img)

# %%
img = plt.imread('/content/pytorch-CycleGAN-and-pix2pix/results/horse2zebra_pretrained/test_latest/images/Many Horse Image-2_real.png')
plt.imshow(img)

# %%
img = plt.imread('/content/pytorch-CycleGAN-and-pix2pix/results/horse2zebra_pretrained/test_latest/images/Many Horse Image_fake.png')
plt.imshow(img)

# %%
img = plt.imread('/content/pytorch-CycleGAN-and-pix2pix/results/horse2zebra_pretrained/test_latest/images/Many Horse Image_real.png')
plt.imshow(img)

# %% [markdown]
# ### (d) Implement on Another Dataset

# %% [markdown]
# ### Apple2Orange CycleGAN

# %%
# !bash ./datasets/download_cyclegan_dataset.sh apple2orange
# Out:
# Specified [apple2orange]
# WARNING: timestamping does nothing in combination with -O. See the manual
# for details.
#
# --2021-10-28 22:11:16--  http://efrosgans.eecs.berkeley.edu/cyclegan/datasets/apple2orange.zip
# Resolving efrosgans.eecs.berkeley.edu (efrosgans.eecs.berkeley.edu)... 128.32.244.190
# Connecting to efrosgans.eecs.berkeley.edu (efrosgans.eecs.berkeley.edu)|128.32.244.190|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 78456409 (75M) [application/zip]
# Saving to: ‘./datasets/apple2orange.zip’
#
# ./datasets/apple2or 100%[===================>]  74.82M  5.40MB/s    in 16s
#
# 2021-10-28 22:11:32 (4.59 MB/s) - ‘./datasets/apple2orange.zip’ saved [78456409/78456409]
#
# Archive:  ./datasets/apple2orange.zip
#    creating: ./datasets/apple2orange/trainA/
#   inflating: ./datasets/apple2orange/trainA/n07740461_6908.jpg
#   inflating: ./datasets/apple2orange/trainA/n07740461_7635.jpg
# ...

# %%
# !bash ./scripts/download_cyclegan_model.sh apple2orange
# Out:
# Note: available models are apple2orange, orange2apple, summer2winter_yosemite, winter2summer_yosemite, horse2zebra, zebra2horse, monet2photo, style_monet, style_cezanne, style_ukiyoe, style_vangogh, sat2map, map2sat, cityscapes_photo2label, cityscapes_label2photo, facades_photo2label, facades_label2photo, iphone2dslr_flower
# Specified [apple2orange]
# WARNING: timestamping does nothing in combination with -O. See the manual
# for details.
#
# --2021-10-28 22:11:34--  http://efrosgans.eecs.berkeley.edu/cyclegan/pretrained_models/apple2orange.pth
# Resolving efrosgans.eecs.berkeley.edu (efrosgans.eecs.berkeley.edu)... 128.32.244.190
# Connecting to efrosgans.eecs.berkeley.edu (efrosgans.eecs.berkeley.edu)|128.32.244.190|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 45575747 (43M)
# Saving to: ‘./checkpoints/apple2orange_pretrained/latest_net_G.pth’
#
# ./checkpoints/apple 100%[===================>]  43.46M  3.99MB/s    in 11s
#
# ...

# %%
# !python test.py --dataroot datasets/apple2orange/testA --name apple2orange_pretrained --model test --no_dropout
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#                 crop_size: 256
#                  dataroot: datasets/apple2orange/testA   	[default: None]
#              dataset_mode: single
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
#                     model: test
#              model_suffix:
#                n_layers_D: 3
#                      name: apple2orange_pretrained       	[default: experiment_name]
#                       ndf: 64
# ...

# %%
img = plt.imread('/content/pytorch-CycleGAN-and-pix2pix/results/apple2orange_pretrained/test_latest/images/n07740461_10080_real.png')
plt.imshow(img)

# %%
img = plt.imread('/content/pytorch-CycleGAN-and-pix2pix/results/apple2orange_pretrained/test_latest/images/n07740461_10080_fake.png')
plt.imshow(img)

# %% [markdown]
# ### Summer2Winter_Yosemite CycleGAN

# %%
# !bash ./datasets/download_cyclegan_dataset.sh summer2winter_yosemite
# Out:
# Specified [summer2winter_yosemite]
# WARNING: timestamping does nothing in combination with -O. See the manual
# for details.
#
# --2021-10-28 22:11:55--  http://efrosgans.eecs.berkeley.edu/cyclegan/datasets/summer2winter_yosemite.zip
# Resolving efrosgans.eecs.berkeley.edu (efrosgans.eecs.berkeley.edu)... 128.32.244.190
# Connecting to efrosgans.eecs.berkeley.edu (efrosgans.eecs.berkeley.edu)|128.32.244.190|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 132640856 (126M) [application/zip]
# Saving to: ‘./datasets/summer2winter_yosemite.zip’
#
# ./datasets/summer2w 100%[===================>] 126.50M  4.15MB/s    in 31s
#
# 2021-10-28 22:12:26 (4.03 MB/s) - ‘./datasets/summer2winter_yosemite.zip’ saved [132640856/132640856]
#
# Archive:  ./datasets/summer2winter_yosemite.zip
#    creating: ./datasets/summer2winter_yosemite/trainA/
#   inflating: ./datasets/summer2winter_yosemite/trainA/2014-07-01 10:31:48.jpg
# ...

# %%
# !bash ./scripts/download_cyclegan_model.sh summer2winter_yosemite
# Out:
# Note: available models are apple2orange, orange2apple, summer2winter_yosemite, winter2summer_yosemite, horse2zebra, zebra2horse, monet2photo, style_monet, style_cezanne, style_ukiyoe, style_vangogh, sat2map, map2sat, cityscapes_photo2label, cityscapes_label2photo, facades_photo2label, facades_label2photo, iphone2dslr_flower
# Specified [summer2winter_yosemite]
# WARNING: timestamping does nothing in combination with -O. See the manual
# for details.
#
# --2021-10-28 22:12:28--  http://efrosgans.eecs.berkeley.edu/cyclegan/pretrained_models/summer2winter_yosemite.pth
# Resolving efrosgans.eecs.berkeley.edu (efrosgans.eecs.berkeley.edu)... 128.32.244.190
# Connecting to efrosgans.eecs.berkeley.edu (efrosgans.eecs.berkeley.edu)|128.32.244.190|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 45575747 (43M)
# Saving to: ‘./checkpoints/summer2winter_yosemite_pretrained/latest_net_G.pth’
#
# ...

# %%
# !python test.py --dataroot datasets/summer2winter_yosemite/testA --name summer2winter_yosemite_pretrained --model test --no_dropout
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#                 crop_size: 256
#                  dataroot: datasets/summer2winter_yosemite/testA	[default: None]
#              dataset_mode: single
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
#                     model: test
#              model_suffix:
#                n_layers_D: 3
#                      name: summer2winter_yosemite_pretrained	[default: experiment_name]
# ...

# %%
img = plt.imread('/content/pytorch-CycleGAN-and-pix2pix/results/summer2winter_yosemite_pretrained/test_latest/images/2010-09-07 12:23:20_fake.png')
plt.imshow(img)

# %%
img = plt.imread('/content/pytorch-CycleGAN-and-pix2pix/results/summer2winter_yosemite_pretrained/test_latest/images/2010-09-07 12:23:20_real.png')
plt.imshow(img)
